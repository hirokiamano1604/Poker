# %% [markdown]
# # Lack of Robustness of the Markowitz Procedure and the GMV

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import edhec_risk_kit as erk
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.optimize import minimize

ind = erk.get_ind_returns()
er = erk.annualize_rets(ind["1996":"2000"],12)
cov = ind["1996":"2000"].cov()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Applications/SelfStudy/PythonForPortfolio/Module 2/edhec_risk_kit.py:51: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ind = pd.read_csv("../data/ind30_m_vw_rets.csv", header = 0, index_col = 0, parse_dates= True) /100

# %%
l = ["Food", "Steel"]
erk.msr(0.1, er[l], cov.loc[l,l])
# Out:
# array([0.75040364, 0.24959636])

# %%
er[l]
# Out:
# Food     0.116799
# Steel    0.115809
# dtype: float64

# %%
erk.msr(0.1, np.array([0.11, 0.12]),cov.loc[l,l])
# Out:
# array([0.57930356, 0.42069644])

# %% [markdown]
# The slight differences in the expected return makes differences according to this analysis.

# %%
erk.msr(0.1, np.array([0.10, 0.13]),cov.loc[l,l])
# Out:
# array([2.08166817e-17, 1.00000000e+00])

# %%
erk.msr(0.1, np.array([.13, .11]),cov.loc[l,l])
# Out:
# array([0.90026056, 0.09973944])

# %%
erk.plot_ef(20, er, cov, show_cml = True, riskfree_rate = 0.1, show_ew = True)
plt.show()
# Out:
# /Applications/SelfStudy/PythonForPortfolio/Module 2/edhec_risk_kit.py:208: OptimizeWarning: Unknown solver options: drop
#   results = minimize(portfolio_vol,
# /Applications/SelfStudy/PythonForPortfolio/Module 2/edhec_risk_kit.py:208: OptimizeWarning: Unknown solver options: drop
#   results = minimize(portfolio_vol,
# /Applications/SelfStudy/PythonForPortfolio/Module 2/edhec_risk_kit.py:208: OptimizeWarning: Unknown solver options: drop
#   results = minimize(portfolio_vol,
# /Applications/SelfStudy/PythonForPortfolio/Module 2/edhec_risk_kit.py:208: OptimizeWarning: Unknown solver options: drop
#   results = minimize(portfolio_vol,
# /Applications/SelfStudy/PythonForPortfolio/Module 2/edhec_risk_kit.py:208: OptimizeWarning: Unknown solver options: drop
#   results = minimize(portfolio_vol,
# /Applications/SelfStudy/PythonForPortfolio/Module 2/edhec_risk_kit.py:208: OptimizeWarning: Unknown solver options: drop
#   results = minimize(portfolio_vol,
# ...

# %%
erk.plot_ef(20, er, cov, show_cml = True, riskfree_rate = 0.1, show_ew = True, show_gmv=True)
plt.show()
# Out:
# /Applications/SelfStudy/PythonForPortfolio/Module 2/edhec_risk_kit.py:208: OptimizeWarning: Unknown solver options: drop
#   results = minimize(portfolio_vol,
# /Applications/SelfStudy/PythonForPortfolio/Module 2/edhec_risk_kit.py:208: OptimizeWarning: Unknown solver options: drop
#   results = minimize(portfolio_vol,
# /Applications/SelfStudy/PythonForPortfolio/Module 2/edhec_risk_kit.py:208: OptimizeWarning: Unknown solver options: drop
#   results = minimize(portfolio_vol,
# /Applications/SelfStudy/PythonForPortfolio/Module 2/edhec_risk_kit.py:208: OptimizeWarning: Unknown solver options: drop
#   results = minimize(portfolio_vol,
# /Applications/SelfStudy/PythonForPortfolio/Module 2/edhec_risk_kit.py:208: OptimizeWarning: Unknown solver options: drop
#   results = minimize(portfolio_vol,
# /Applications/SelfStudy/PythonForPortfolio/Module 2/edhec_risk_kit.py:208: OptimizeWarning: Unknown solver options: drop
#   results = minimize(portfolio_vol,
# ...
