# %% [markdown]
# # Building Modules

# %%
#We can use these modile bu importing.
import pandas as pd

# %%
import hello as h

# %%
h.message
# Out:
# 'Hello Hiroki'

# %%
#magic command
# %load_ext autoreload
#this is very convinient for the module development

# %%
# %autoreload 2

# %%
h.message
# Out:
# 'Hello Hiroki'

# %%
h.message
# Out:
# 'Hello Jane and Jim'

# %%
h.message
# Out:
# 'Hello Jane and Jim and Kim'

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import edhec_risk_kit as erk

returns = erk.gett_ffme_returns()

# %%
returns.head()
# Out:
#          SmallCap  LargeCap
# 1926-07   -0.0145    0.0329
# 1926-08    0.0512    0.0370
# 1926-09    0.0093    0.0067
# 1926-10   -0.0484   -0.0243
# 1926-11   -0.0078    0.0270

# %%
erk.drawdown(returns["SmallCap"])["Drawdown"].min()
# Out:
# -0.8330007793945303

# %%
erk.drawdown(returns["1975":]["SmallCap"])["Drawdown"].min()
# Out:
# -0.6312068077252386
